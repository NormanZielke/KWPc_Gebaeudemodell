# %%
from pathlib import Path
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %% [markdown]
# ## Gebäudemodell HN

# %%
GPKG_PATH = (
    "1_Rohdaten/HN/HN-Gebäudemodell/"
    "HN-Gebäudemodell_04_08_2026/"
    "260728_Gebäudemodell_HohenNeuendorf.gpkg"
)

# %%
gdf = gpd.read_file(GPKG_PATH)

# %%
demand_kwh_ges = gdf["demand_kwh"].sum()*1e-6
print("Wärmeverbrauch über alle Einträge beträgt", round(demand_kwh_ges,2), "GWh")
# Out:
# Wärmeverbrauch über alle Einträge beträgt 213.99 GWh

# %%
gdf_with_ID = gdf[~gdf["GebaeudeID"].isna()]
demand_kwh_ID = gdf_with_ID["demand_kwh"].sum()*1e-6
gdf_with_function = gdf[~gdf["funktion"].isna()]
demand_kwh_function = gdf_with_function["demand_kwh"].sum()*1e-6
print("Wärmeverbrauch über alle Gebäude_ID beträgt", round(demand_kwh_ID,2), "GWh")
print("Es gibt",len(gdf_with_ID), "mit Gebaeude_ID")
print("Wärmeverbrauch über alle Gebäude ohne Gebäude_ID und mit funktion beträgt", round(round(demand_kwh_ges,2) - round(demand_kwh_ID,2),2), "GWh")
print("Wärmeverbrauch über alle Gebäude ohne Gebäude_ID und mit funktion beträgt", round(demand_kwh_function,2), "GWh")
print("Es gibt",len(gdf_with_function), "ohne Gebaeude_ID")
# Out:
# Wärmeverbrauch über alle Gebäude_ID beträgt 189.63 GWh
# Es gibt 9550 mit Gebaeude_ID
# Wärmeverbrauch über alle Gebäude ohne Gebäude_ID und mit funktion beträgt 24.36 GWh
# Wärmeverbrauch über alle Gebäude ohne Gebäude_ID und mit funktion beträgt 24.36 GWh
# Es gibt 2279 ohne Gebaeude_ID

# %%
len(gdf_with_ID)
# Out:
# 9550

# %%
gdf_with_funktion = gdf[~gdf["funktion"].isna()]
df = gdf[~gdf["funktion"].isna() & ~gdf["GebaeudeID"].isna()]
print(df)
print("Es gibt keine Gebäude, die ein Funktion und eine Gebäude_ID haben")
# Out:
# Empty GeoDataFrame
# Columns: [GebaeudeID, StrName, Hausnummer, Stadtteil, PLZ, Gemeinde, AGS, Landkreis, Flur, Flurstueck, Gemarkung, BauAltKl, GebTyp, NutzungArt, AnzlWhg, SolarPot_k, Waermebed_, ETraeger1, ETraeger2, HzngTec1, HzngTec2, EndEVer_RW, EndEVer_kw, CO2_RW_tco, CO2_tco2_a, Datenquali, gemeinde_n, Etagen, funktion, heating_carrier, Bedarf_katatster, Nutzung, Baualter_int, komm, sector, demand_kwh, denkmal, hoehe_korr, etagen_fin, nutzflaeche_korr, P_th, demand_spec, demand_2030, demand_2035, demand_2040, demand_2045, demand_spec_san, geometry]
# Index: []
#
# [0 rows x 48 columns]
# Es gibt keine Gebäude, die ein Funktion und eine Gebäude_ID haben

# %%
gdf["ETraeger1"].unique()
# Out:
# array(['FesteBiomasse', 'Gas', 'Oel', 'Strom'], dtype=object)

# %%
gdf["ETraeger2"].unique()
# Out:
# array([None, 'Feste_Biomasse', 'Solarthermie'], dtype=object)

# %% [markdown]
# ### Identifier in "funktion", "NutzungArt" und "GebTyp"

# %%
print(gdf["funktion"].unique())
print(gdf["funktion"].unique().size)
# Out:
# [None 'Garage' 'Nach Quellenlage nicht zu spezifizieren'
#  'Land- und forstwirtschaftliches Betriebsgebäude'
#  'Gebäude zur Freizeitgestaltung' 'Überdachung' 'Schuppen'
#  'Gebäude für Wirtschaft oder Gewerbe' 'Tiefgarage'
#  'Wohngebäude mit Handel und Dienstleistungen' 'Werkstatt' 'Fahrzeughalle'
#  'Wohnhaus' 'Sport-, Turnhalle' 'Gebäude zur Elektrizitätsversorgung'
#  'Wochenendhaus' 'Stall' 'Gebäude zum Parken'
#  'Lagerhalle, Lagerschuppen, Lagerhaus' 'Stellwerk, Blockstelle' 'Kirche'
#  'Gebäude für Sportzwecke' 'Gebäude für Vorratshaltung' 'Pumpstation'
#  'Gartenhaus' 'Tankstelle' 'Gebäude für religiöse Zwecke'
#  'Treibhaus, Gewächshaus' 'Scheune' 'Umformer' 'Sonstiges'
#  'Gebäude zur Abfallbehandlung' 'Gebäude zur Versorgungsanlage'
#  'Betriebsgebäude für Schienenverkehr' 'Gebäude für Gewerbe und Industrie'
#  'Kapelle' 'Einkaufszentrum' 'Heizwerk' 'Produktionsgebäude']
# 39

# %%
print(gdf["NutzungArt"].unique())
print(gdf["NutzungArt"].unique().size)
# Out:
# ['Freizeit- und Vergn�gungsst�tte' 'Geb�ude f�r Wirtschaft oder Gewerbe'
#  'Wohnheim' 'Wohnhaus' None 'Hotel, Motel, Pension'
#  'Geb�ude f�r soziale Zwecke' 'Feuerwehr'
#  'Wohngeb�ude mit Gewerbe und Industrie'
#  'Wohngeb�ude mit Handel und Dienstleistungen'
#  'Geb�ude f�r Bildung und Forschung' 'Wohngeb�ude' 'Forschungsinstitut'
#  'Wochenendhaus' 'Kinderkrippe, Kindergarten, Kindertagesst�tte'
#  'Allgemein bildende Schule' 'Geb�ude f�r Handel und Dienstleistungen'
#  'Verwaltungsgeb�ude' 'Geb�ude f�r Gesundheitswesen'
#  'Geb�ude f�r Gewerbe und Industrie mit Wohnen' 'Rathaus' 'B�rogeb�ude'
#  'Geb�ude f�r Handel und Dienstleistung mit Wohnen'
#  'Geb�ude f�r Bewirtung' 'Geb�ude f�r kulturelle Zwecke'
#  'Geb�ude f�r �ffentliche Zwecke'
#  'Geb�ude f�r betriebliche Sozialeinrichtung' 'Wohn- und Gesch�ftsgeb�ude'
#  'Gastst�tte, Restaurant' 'Produktionsgeb�ude'
#  'Wohngeb�ude mit Gemeinbedarf' 'Gesch�ftsgeb�ude'
#  'Geb�ude f�r Beherbergung' 'Geb�ude f�r Sicherheit und Ordnung'
#  'Empfangsgeb�ude' '�rztehaus, Poliklinik' 'Kaufhaus' 'Betriebsgeb�ude'
#  'Polizei' 'Kreditinstitut']
# 40

# %%
print(gdf["GebTyp"].unique())
print(gdf["GebTyp"].unique().size)
# Out:
# ['Geb�ude f�r Kultur und Freizeit' 'B�ro-, Verwaltungs- oder Amtsgeb�ude'
#  'MFH' 'EFH' None 'GMH'
#  'Beherbergungs- oder Unterbringungsgeb�ude, Gastronomie- oder Verpflegungsgeb�ude'
#  'Verkehrsgeb�ude' 'Geb�ude f�r Forschung und Hochschullehre' 'RH'
#  'Schule, Kindertagesst�tte und sonstiges Betreuungsgeb�ude'
#  'Handelsgeb�ude' 'Geb�ude f�r Gesundheit und Pflege'
#  'Produktions-, Werkstatt-, Lager- oder Betriebsgeb�ude']
# 14

# %%
gdf_with_funktion = gdf[~gdf["funktion"].isna()]
df = gdf[~gdf["funktion"].isna() & ~gdf["GebTyp"].isna()]
print(df)
print("Es gibt keine Gebäude, die ein Funktion und eine GebTyp haben")
# Out:
# Empty GeoDataFrame
# Columns: [GebaeudeID, StrName, Hausnummer, Stadtteil, PLZ, Gemeinde, AGS, Landkreis, Flur, Flurstueck, Gemarkung, BauAltKl, GebTyp, NutzungArt, AnzlWhg, SolarPot_k, Waermebed_, ETraeger1, ETraeger2, HzngTec1, HzngTec2, EndEVer_RW, EndEVer_kw, CO2_RW_tco, CO2_tco2_a, Datenquali, gemeinde_n, Etagen, funktion, heating_carrier, Bedarf_katatster, Nutzung, Baualter_int, komm, sector, demand_kwh, denkmal, hoehe_korr, etagen_fin, nutzflaeche_korr, P_th, demand_spec, demand_2030, demand_2035, demand_2040, demand_2045, demand_spec_san, geometry]
# Index: []
#
# [0 rows x 48 columns]
# Es gibt keine Gebäude, die ein Funktion und eine GebTyp haben

# %%
#gdf[~gdf["GebTyp"].isna()]

# %% [markdown]
# ## ALKIS

# %%
Alkis_GPKG_PATH = (
    "1_Rohdaten/HN/HN-Gebäudemodell/"
    "HN-Gebäudemodell_04_08_2026/"
    "alkis_EG_HN.gpkg"
)

Alkis_gdf = gpd.read_file(Alkis_GPKG_PATH)

# %%
Alkis_gdf.columns
# Out:
# Index(['identifier', 'oid', 'aktualit', 'gebnutzbez', 'funktion', 'gfkzshh',
#        'rellage', 'name', 'anzahlgs', 'gmdschl', 'lagebeztxt', 'geometry'],
#       dtype='object')

# %%
Alkis_gdf
# Out:
#                            identifier                 oid     aktualit  \
# 0      urn:adv:oid:DEBBAL010007AF5xBL  DEBBAL010007AF5xBL  2013-11-18Z
# 1      urn:adv:oid:DEBBAL010007AkpIBL  DEBBAL010007AkpIBL  2013-11-13Z
# 2      urn:adv:oid:DEBBAL010007AkpJBL  DEBBAL010007AkpJBL  2013-11-13Z
# 3      urn:adv:oid:DEBBAL010007CalSBL  DEBBAL010007CalSBL  2013-11-28Z
# 4      urn:adv:oid:DEBBAL010007Cm6EBL  DEBBAL010007Cm6EBL  2013-11-29Z
# ...                               ...                 ...          ...
# 35279  urn:adv:oid:DEBBAL01000doQvRBL  DEBBAL01000doQvRBL  2026-09-15Z
# 35280  urn:adv:oid:DEBBAL01000doQvTBL  DEBBAL01000doQvTBL  2026-09-15Z
# 35281  urn:adv:oid:DEBBAL01000doQvVBL  DEBBAL01000doQvVBL  2026-09-15Z
# 35282  urn:adv:oid:DEBBAL01000doQvXBL  DEBBAL01000doQvXBL  2026-09-15Z
# 35283  urn:adv:oid:DEBBAL01000doQvZBL  DEBBAL01000doQvZBL  2026-09-15Z
#
#       gebnutzbez                             funktion     gfkzshh rellage  \
# 0        Gebäude                               Garage  31001_2463    None
# 1        Gebäude  Gebäude für Wirtschaft oder Gewerbe  31001_2000    None
# 2        Gebäude  Gebäude für Wirtschaft oder Gewerbe  31001_2000    None
# 3        Gebäude                             Wohnhaus  31001_1010    None
# 4        Gebäude                             Wohnhaus  31001_1010    None
# ...          ...                                  ...         ...     ...
# 35279    Gebäude                             Wohnhaus  31001_1010    None
# 35280    Gebäude                             Wohnhaus  31001_1010    None
# 35281    Gebäude                             Wohnhaus  31001_1010    None
# 35282    Gebäude                             Wohnhaus  31001_1010    None
# 35283    Gebäude                             Wohnhaus  31001_1010    None
#
#        name  anzahlgs   gmdschl       lagebeztxt  \
# 0      None       1.0  12065144             None
# 1      None       NaN  12065144             None
# 2      None       NaN  12065144             None
# 3      None       2.0  12065036  Kleiststraße 31
# 4      None       1.0  12065144             None
# ...     ...       ...       ...              ...
# 35279  None       2.0  12065144             None
# 35280  None       2.0  12065144             None
# 35281  None       2.0  12065144             None
# 35282  None       2.0  12065144             None
# 35283  None       2.0  12065144             None
#
#                                                 geometry
# 0      MULTIPOLYGON (((381288.558 5837904.589, 381288...
# 1      MULTIPOLYGON (((384886.546 5837191.671, 384886...
# 2      MULTIPOLYGON (((384886.858 5837189.2, 384886.9...
# 3      MULTIPOLYGON (((384308.261 5838595.856, 384303...
# 4      MULTIPOLYGON (((384065.173 5836619.284, 384066...
# ...                                                  ...
# 35279  MULTIPOLYGON (((382750.004 5837182.637, 382759...
# 35280  MULTIPOLYGON (((382728.404 5837206.29, 382738....
# 35281  MULTIPOLYGON (((382715.962 5837185.958, 382725...
# 35282  MULTIPOLYGON (((382694.352 5837209.612, 382704...
# 35283  MULTIPOLYGON (((382681.897 5837189.234, 382691...
#
# [35284 rows x 12 columns]

# %% [markdown]
# ## Wärmekatastar

# %%
WK_GPKG_PATH = (
    "1_Rohdaten/HN/HN-Gebäudemodell/"
    "HN-Gebäudemodell_04_08_2026/"
    "WK_EG_HN.gpkg"
)

WK_gdf = gpd.read_file(WK_GPKG_PATH)

# %%
WK_gdf.columns
# Out:
# Index(['GebaeudeID', 'StrName', 'Hausnummer', 'Stadtteil', 'PLZ', 'Gemeinde',
#        'AGS', 'Landkreis', 'Flur', 'Flurstueck', 'Gemarkung', 'GrundFl_qm',
#        'BruGeschFl_qm', 'BauAltKl', 'GebTyp', 'NutzungArt', 'AnzlWhg',
#        'SolarPot_kwh_a', 'Waermebed_kwh_a', 'ETraeger1', 'ETraeger2',
#        'HzngTec1', 'HzngTec2', 'EndEVer_RW_kwh_a', 'EndEVer_kwh_a',
#        'CO2_RW_tco2_a', 'CO2_tco2_a', 'Datenqualitaet', 'gemeinde_name',
#        'geometry'],
#       dtype='object')

# %%
WK_gdf
# Out:
#                GebaeudeID                   StrName Hausnummer  Stadtteil  \
# 0      DEBBAL010007CalSBL              Kleiststraße         31        NaN
# 1      DEBBAL010007PVQEBL                 Seestraße         13        NaN
# 2      DEBBAL010007Qp5ZBL  Friedrich-Naumann-Straße         60        NaN
# 3      DEBBAL010007RJKYBL                  Forstweg         18        NaN
# 4      DEBBAL010007Rof6BL               Eichenallee         27        NaN
# ...                   ...                       ...        ...        ...
# 18260  DEBBAL650004OTibBL               Rheinstraße         70        NaN
# 18261  DEBBAL650004OTisBL               Rheinstraße         77        NaN
# 18262  DEBBAL650004OTiwBL                  Pankeweg         11        NaN
# 18263  DEBBAL0100098NGwBL          Mühlenbecker Weg        519        NaN
# 18264  DEBBAL01000cqFjnBL          Mühlenbecker Weg          5        NaN
#
#        PLZ         Gemeinde       AGS  Landkreis Flur Flurstueck  ...  \
# 0      NaN     Birkenwerder  12065036  Oberhavel  003        295  ...
# 1      NaN  Hohen Neuendorf  12065144  Oberhavel  001        823  ...
# 2      NaN  Hohen Neuendorf  12065144  Oberhavel  010        843  ...
# 3      NaN  Hohen Neuendorf  12065144  Oberhavel  002         17  ...
# 4      NaN  Hohen Neuendorf  12065144  Oberhavel  010       1958  ...
# ...    ...              ...       ...        ...  ...        ...  ...
# 18260  NaN      Oranienburg  12065256  Oberhavel  025      160/5  ...
# 18261  NaN      Oranienburg  12065256  Oberhavel  025      155/1  ...
# 18262  NaN      Oranienburg  12065256  Oberhavel  025     156/11  ...
# 18263  NaN  Hohen Neuendorf  12065144  Oberhavel  005        519  ...
# 18264  NaN      Oranienburg  12065256  Oberhavel  003        692  ...
#
#             ETraeger2            HzngTec1         HzngTec2 EndEVer_RW_kwh_a  \
# 0                None           Gaskessel              nan          17228.0
# 1                None           Gaskessel              nan          21752.0
# 2                None           Gaskessel              nan          22598.0
# 3                None           Gaskessel              nan          33044.0
# 4                None           Gaskessel             none          13310.0
# ...               ...                 ...              ...              ...
# 18260            None           Gaskessel              nan           9715.0
# 18261  Feste_Biomasse  Wärmepumpe (Strom)  Kamin (Bestand)           6540.0
# 18262            None           Gaskessel              nan           5386.0
# 18263            None           Sonstiges             None              NaN
# 18264            None           Sonstiges             None              NaN
#
#       EndEVer_kwh_a CO2_RW_tco2_a CO2_tco2_a  Datenqualitaet    gemeinde_name  \
# 0           17228.0           3.0        3.0               B     Birkenwerder
# 1           21752.0           4.0        4.0               B  Hohen Neuendorf
# 2           22598.0           5.0        5.0               B  Hohen Neuendorf
# 3           33044.0           7.0        7.0               B  Hohen Neuendorf
# 4           13310.0           3.0        3.0               B  Hohen Neuendorf
# ...             ...           ...        ...             ...              ...
# 18260        9715.0           2.0        2.0               B      Oranienburg
# 18261        6540.0           3.0        3.0               B      Oranienburg
# 18262        5386.0           1.0        1.0               B      Oranienburg
# 18263     8382935.0           NaN     2604.0               C  Hohen Neuendorf
# 18264    13134346.0           NaN     3537.0               C      Oranienburg
#
#                                                 geometry
# 0      POLYGON ((384309.399 5838590.285, 384307.634 5...
# 1      POLYGON ((383697.556 5838473.331, 383706.916 5...
# 2      POLYGON ((382644.669 5837230.242, 382655.147 5...
# 3      POLYGON ((386336.047 5838848.282, 386343.988 5...
# 4      POLYGON ((382730.421 5836867.231, 382739.963 5...
# ...                                                  ...
# 18260  POLYGON ((382039.436 5844450.424, 382039.682 5...
# 18261  POLYGON ((382081.4 5844441.57, 382074.06 58444...
# 18262  POLYGON ((382163.68 5844462.39, 382162.83 5844...
# 18263  POLYGON ((383284.204 5844546.361, 383311.736 5...
# 18264  POLYGON ((382898.714 5844873.462, 382904.076 5...
#
# [18265 rows x 30 columns]

# %%
gdf.columns
# Out:
# Index(['GebaeudeID', 'StrName', 'Hausnummer', 'Stadtteil', 'PLZ', 'Gemeinde',
#        'AGS', 'Landkreis', 'Flur', 'Flurstueck', 'Gemarkung', 'BauAltKl',
#        'GebTyp', 'NutzungArt', 'AnzlWhg', 'SolarPot_k', 'Waermebed_',
#        'ETraeger1', 'ETraeger2', 'HzngTec1', 'HzngTec2', 'EndEVer_RW',
#        'EndEVer_kw', 'CO2_RW_tco', 'CO2_tco2_a', 'Datenquali', 'gemeinde_n',
#        'Etagen', 'funktion', 'heating_carrier', 'Bedarf_katatster', 'Nutzung',
#        'Baualter_int', 'komm', 'sector', 'demand_kwh', 'denkmal', 'hoehe_korr',
#        'etagen_fin', 'nutzflaeche_korr', 'P_th', 'demand_spec', 'demand_2030',
#        'demand_2035', 'demand_2040', 'demand_2045', 'demand_spec_san',
#        'geometry'],
#       dtype='object')

# %%
Alkis_gdf.columns
# Out:
# Index(['identifier', 'oid', 'aktualit', 'gebnutzbez', 'funktion', 'gfkzshh',
#        'rellage', 'name', 'anzahlgs', 'gmdschl', 'lagebeztxt', 'geometry'],
#       dtype='object')

# %%
WK_gdf.columns
# Out:
# Index(['GebaeudeID', 'StrName', 'Hausnummer', 'Stadtteil', 'PLZ', 'Gemeinde',
#        'AGS', 'Landkreis', 'Flur', 'Flurstueck', 'Gemarkung', 'GrundFl_qm',
#        'BruGeschFl_qm', 'BauAltKl', 'GebTyp', 'NutzungArt', 'AnzlWhg',
#        'SolarPot_kwh_a', 'Waermebed_kwh_a', 'ETraeger1', 'ETraeger2',
#        'HzngTec1', 'HzngTec2', 'EndEVer_RW_kwh_a', 'EndEVer_kwh_a',
#        'CO2_RW_tco2_a', 'CO2_tco2_a', 'Datenqualitaet', 'gemeinde_name',
#        'geometry'],
#       dtype='object')
